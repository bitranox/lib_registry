# %% [markdown]
# # lib_registry Quickstart
#
# Install the package (from PyPI or GitHub), then try the CLI and API examples below.

# %% [markdown]
# ## 1) Install latest from GitHub (default)

# %%
# update pip and setuptools
import sys

# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install --upgrade setuptools

# install lib_registry from GitHub (default)
# !{sys.executable} -m pip install --upgrade git+https://github.com/bitranox/lib_registry.git

# %% [markdown]
# ## Or: Install from PyPI (alternative)
# Uncomment and run the cell below if you prefer the PyPI release.

# %%
# !{sys.executable} -m pip install --upgrade lib_registry

# %% [markdown]
# ## 2) CLI: version and help

# %%
# !lib_registry --version
# !lib_registry --help
# !lib_registry info
# !lib_registry hello
# !lib_registry fail

# %% [markdown]
# ## 3) CLI fail without traceback

# %%
# !lib_registry fail

# %% [markdown]
# ## 4) CLI fail with traceback

# %%
# !lib_registry --traceback fail

# %% [markdown]
# ## 5) script fail without traceback

# %%
# !{sys.executable} -m lib_registry fail

# %% [markdown]
# ## 6) script fail with traceback

# %%
# !{sys.executable} -m lib_registry --traceback fail
